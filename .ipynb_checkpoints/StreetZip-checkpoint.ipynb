# %%
"""
Converting NYC Street names to Zip Codes
"""

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/example_streets.csv')
df
# Out:
#                 streets  zipcodes
# 0          beach street       NaN
# 1     little clove road       NaN
# 2    narrows road south       NaN
# 3         ocean terrace       NaN
# 4                bay st       NaN
# ..                  ...       ...
# 892    west 53rd street       NaN
# 893    west 55th street       NaN
# 894    west 56th street       NaN
# 895    west 57th street       NaN
# 896    west 49th street       NaN
#
# [897 rows x 2 columns]

# %%
def street_to_zip(street_name):
    # TODO: finalize
    ...
    
    # manual version:
    translate_df = pd.read_csv('data/example_streets.csv')
    search_df = translate_df[translate_df["streets"].str.contains(street_name)]
    return search_df.iloc[0].zipcodes

# %%
for test_street in test_case["streets"]:
    print(test_street, "=>", street_to_zip(test_street))
# Out:
# beach street => nan
# little clove road => nan
# narrows road south => nan
# ocean terrace => nan
# bay st => nan
# clove rd => nan
# hylan blvd => nan
# manor rd => nan
# targee st => nan
# todt hill rd => nan
# van duzer street => nan
# victory boulevard => nan
# morgan ave => nan
# park avenue => nan
# 8 ave => nan
# kingsland avenue => nan
# lewis ave => nan
# humboldt street => nan
# kent avenue => nan
# ralph ave => nan
# rockaway ave => nan
# stuyvesant avenue => nan
# throop avenue => nan
# union avenue => nan
# malcolm x blvd => nan
# graham avenue => nan
# greene avenue => nan
# greenpoint avenue => nan
# kingston ave => nan
# 3 ave => nan
# 4 ave => nan
# 5 ave => nan
# 6 ave => nan
# 7 ave => nan
# new york ave => nan
# quincy st => nan
# smith st => nan
# tompkins ave => nan
# union st => nan
# van brunt st => nan
# vanderbilt ave => nan
# washington ave => nan
# putnam ave => nan
# castleton avenue => nan
# marcus garvey blvd => nan
# franklin av => nan
# ...

# %%
# df["zipcodes"] = df["streets"].apply(lambda x: street_to_zip(x))
